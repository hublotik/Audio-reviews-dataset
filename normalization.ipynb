# %%
from pathlib import Path
import pandas as pd
Path.cwd()
df_amp = pd.read_csv(f"/..{Path.cwd()}/parse/final_amp.csv")

# %%
df_amp
# Out:
#                                      uuid                       Name   THD  \
# 0    487bdeb2-053d-4e6c-8402-7c59e37785d2  McIntosh Laboratory MC462  0.00
# 1    64bb10e3-a88d-418c-9190-28713032170e              Primare A35.8  0.00
# 2    a245f6d0-6af0-4571-a472-7b1efea8266e                  NAD C 298  0.00
# 3    fb80d337-8307-43d4-88cb-c5dac336c400  McIntosh Laboratory MC501  0.00
# 4    2a96cf67-57a6-45c7-8f02-c629dff62df3      Halcro dm88 Reference  0.00
# ..                                    ...                        ...   ...
# 325  121b949a-a9cc-4711-b8ac-637fc25b1dfd              Carver M-1.5t  0.19
# 326  b1fb3ab8-1fdb-4a43-8272-6a19684ccb1f                 SMSL SA100  0.20
# 327  9a0b1fdf-a368-48eb-9760-ce3ee87f45f5         Carver Crimson 275  0.48
# 328  caf863e0-373f-44fb-82d8-94af5f912406           Carver Raven 350  0.62
# 329  3daa8a74-0f89-467d-82f2-2d2b4689cee6                   Pass ACA  2.57
#
#      SINAD  Power  Price       Source  \
# 0      106    720   9000  Stereophile
# 1      101    300   5500  Stereophile
# 2       98    510   2000  Stereophile
# 3       98   1000   8200  Stereophile
# 4       97    525  40000  Stereophile
# ..     ...    ...    ...          ...
# 325     54    236    800          ASR
# 326     54     22     74          ASR
# 327     46     17   2750          ASR
# 328     44    272   9500          ASR
# 329     32      1    320          ASR
#
#                                                 review
# 0    I performed a full set of measurements on the ...
# 1    I tested the Primare A35.8 with my Audio Preci...
# 2    The NAD C 298 can be operated as a conventiona...
# 3    The McIntosh MC501 is unusual for a solid-stat...
# 4    I preconditioned one of the Halcro dm88 monobl...
# ..                                                 ...
# 325   Carver M-1.5t vintage stereo amplifier. It wa...
# 326   SMSL SA100 Stereo Audio Amplifier with analog...
# 327   Carver Crimson 275 tube stereo power amplifie...
# 328   Carver Raven 350 tube monoblock amplifier. It...
# 329   Pass ACA Class A stereo power amplifier.  It ...
#
# [330 rows x 8 columns]

# %% [markdown]
# ### Delete all urls from dataset + unnecessary info

# %%
import re
# split_until_brackets = ['(left', '(fig', '(see', '(linear', '(serial']
cleared_revs = []
repl_list = ['fig.', 'Fig.']
remove_list = ['donations are much appreciated using:', 'I performed a full set of measurements on the', 'I measured the',
              ' I examined the', 'To perform the measurements on the', 'I tested the', 'Before performing any measurements, I ran one of the',
              'I measured one of the', 'Before performing any measurements, I ran', 'To measure the', 'Before I tested one of the',
              'To examine the', 'I examined the', 'As I usually do with amplifiers', 'I preconditioned the', 'I performed a full suite of measurements',
              'A full set of measurements','I performed the measurements of the', 'For logistical reasons, I measured a different sample of the',
              'This is a review and detailed measurements', 'I performed a full set of measurements', 'I made a full set of measurements',
              'To perform measurements on the', 'Before performing any measurements', 'Before performing any test', 'To take these measurements',
              'measurements were taken', 'Before performing tests on an amplifier', 'This is the measurements of the', 'This is a review and measurements of the',
              'A member asked me a while ago to test the', 'This is a write-up and detailed measurements of the', 'This is review and detailed measurements of the',
              'Before doing any testing', 'Before doing any testing', 'Before doing any testing of a power amplifier, I precondition it by running it at one-third its specified power into 8 ohms for 60 minute',
              'It is on kind loan from', 'It was sent to me by the company and', 'It was kindly drop shipped to me by a member and',
              '    a member.  ',  '—John Atkinson', '()', 'It was sent to me by the company', ' I preconditioned it by' , 'with my Audio Precision SYS2722 system',
              'using my Audio Precision SYS2722 system', 'Audio Precision SYS2722', 'Before I test an amplifier', '-------', 'a member and', 'It was kindly purchased new by',
              'I mostly used Stereophiles loan sample of the top-of-the-linesystem ', '; for some tests, I also used my vintage Audio Precision System One Dual Domain and the Miller Audio Research Jitter Analyzer',
              
              '  ',
            ]
for i, revs in enumerate(df_amp.review.to_list()):
    remove_links = re.sub(r'http\S+', '', revs, flags=re.MULTILINE)
    revs_remove_links = re.sub("([\(\[]).*?([\)\]])", "\g<1>\g<2>", remove_links)
    # for isub, substr in enumerate(split_until_brackets):
    #     # substr_i = remove_links.find(substr
    #     if remove_links.find(substr) != -1:
    #         sub_str_appear_list = [values for values in range(len(remove_links)) if remove_links.startswith(substr, values)]
    #         for substr_i in sub_str_appear_list:
    #             braket_i = substr_i + remove_links[substr_i:].find(')')
    #             revs_remove_links = remove_links[:substr_i] + remove_links[braket_i:]
    #             remove_links = revs_remove_links
    for removes in remove_list:
        revs_remove_links = revs_remove_links.replace(removes, ' ')
        
    revs_remove_links = revs_remove_links.split('----As')[0]
    remove_links = revs_remove_links
    
    #     revs_remove_links = remove_links.split(substr)[0] + ''.join(map(str,''.join(map(str,remove_links.split(substr)[1:])).split(')')[1:]))    
    # for sep in repl_list:
    #     revs_remove_links = revs_remove_links.replace(sep, '')
    cleared_revs += [remove_links]

# %%
import string
cleared_revs = [''.join(char for char in item
                    if char not in string.punctuation)
            for item in cleared_revs if item != '']

# %%
from nltk.corpus import stopwords
nltk.download('stopwords')
filtered_sentence = []
arev10_without_stop_words = ''
stop_words = set(stopwords.words('english'))

cleared_revs = [' '.join(words for words in item.split()
                if words not in stop_words)
        for item in cleared_revs if item != '']
# Out:
# [nltk_data] Downloading package stopwords to /home/petr/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
cleared_revs[1]
# Out:
# 'Primare A358 As A358 classD output stages measurements frequency response taken Audio Precisions auxiliary AUX0025 passive lowpass filter mitigates noise 80kHz eliminates noise 200kHz Without filter 325mV ultrasonic noise present pair loudspeaker terminals center frequency 396kHz Because AUX0025 filter twochannel device I could measure two Primares eight channels time Almost measured performance taken channels 6 8 bridgedmode tests performed channels 5 6 linked channels 7 8 linked I dont precondition classD amplifiers testing hours operation top panels temperature stabilized warm 1022°F As Primares twochannel A352 Herb Reichert reviewed May 2020 A358s balanced inputs offered 6dB lower voltage gain 8 ohms singleended inputs 1995dB compared 2595dB The voltage gains bridged mode identical exactly 6dB higher bridged 6 mode The amplifier preserved absolute polarity balanced unbalanced input signals normal bridged modes The balanced input impedance close specified 36k ohms 20Hz 20kHz The unbalanced input impedance specified 15k ohms 147k ohms low middle frequencies dropping slightly inconsequentially 1325k ohms top audiobandIncluding series impedance 6 spacedpair loudspeaker cable A358s output impedance normal mode low 0078 ohm 20Hz 1kHz rising slightly 0092 ohm 20kHz Bridged mode increased impedances slightly The modulation amplifiers frequency response due Ohms law interaction source impedance impedance standard simulated loudspeaker minimal ±01dB The response 8 ohm resistive load taken without Audio Precision lowpass filter flat almost 20kHz rolloff 1dB 30kHz Unusually ultrasonic rolloff disturbed resonant peaks 60kHz 100kHz The Primares reproduction 10kHz squarewave taken Audio Precision lowpass filter waveform obscured ultrasonic noise clean without ringing tops bottom minimal overshootFig1 Primare A358 frequency response 283V simulated loudspeaker load 8 ohms 4 ohms 2 ohms Fig2 Primare A358 smallsignal 10kHz squarewave 8 ohmsSeparation adjacent channels excellent 100dB directions 1kHz reducing still good 76dB top audioband Measured unbalanced inputs shorted ground auxiliary lowpass filter circuit amplifiers unweighted wideband signalnoise ratio good 74dB ref 1W 8 ohms This ratio improved superb 96dB I restricted measurement bandwidth audioband 986dB reading Aweighted Lowlevel spuriae 60Hz power supply frequency harmonics absent Primares lowfrequency noisefloor Fig3 Primare A358 spectrum 1kHz sinewave DC–1kHz 1W 8 ohms Primare specifies A358s maximum power 150W 8 ohms 300W 4 ohms equivalent 2176dBW Using definition clipping outputs percentage THDnoise reaches 1 Primare exceeded specified power two channels driven 8 ohms clipping 200Wpc With two channels driven 4 ohms A358 clipped specified 300Wpc Again two channels operating bridged mode Primare clipped 730W 8 ohms specified 740W load In bridged mode 4 ohms clipping power 1kW compared specified 750WFig4 Primare A358 distortion vs 1kHz continuous output power 8 ohmsFig5 Primare A358 distortion vs 1kHz continuous output power 4 ohmsFig6 Primare A358 bridged mode distortion vs 1kHz continuous output power 8 ohmsI examined percentage THDnoise changed frequency normal mode 20V equivalent 50W 8 ohms 100W 4 ohms 200W 2 ohms The THDN low midrange 8 4 2 ohms rose top octave Peculiarly channel driven separately THDN lower midrange 2 ohms 4 ohms Fig7 Primare A358 THDN vs frequency 20V 8 ohms 4 ohms 2 ohms The A358s distortion 50W 8 ohms low predominantly third harmonic though bursts HF noise coincide waveform peaks even Audio Precision auxiliary filter circuit The third harmonic lay low –108dB channel 8 –103dB channel 6 second harmonic close 10dB lower level channels In bridged mode power 8 ohms third harmonic lay –103dB second fifth harmonics 10dB higher level normal mode With equal mix 19 20kHz tones 100W 4 ohms highorder intermodulation products lay –94dB secondorder difference product 1kHz lay –110dB This spectrum taken normal mode The intermodulation distortion similar bridged modeF ...

# %%
from pathlib import Path
df = pd.DataFrame()
Path.cwd()
for n in range(len(cleared_revs) + 1):
    path_10 = str(Path.cwd()) + '/amp_revs/' + str(n+1)
    df = pd.DataFrame([cleared_revs[n-1]]) 
    df.to_csv(path_10, encoding= 'utf-8', index=None)

# %%
import nltk
from nltk.tokenize import wordpunct_tokenize

# %%
tokens = wordpunct_tokenize(cleared_revs[1])

# %%
d = open(str(Path.cwd()) + '/amp_revs/' + '234', 'r')

# %%
from nltk.corpus.reader import CategorizedPlaintextCorpusReader
newcorpus = CategorizedPlaintextCorpusReader(str(Path.cwd()) + '/amp_revs/', r'.*_.*\.*', cat_pattern = r'.*_(\w+)\.*') 
newcorpus.categories()
# Out:
# []

# %%
newcorpus
# Out:
# <CategorizedPlaintextCorpusReader in '/home/petr/Desktop/Audio-reviews-dataset/amp_revs'>

# %%
newcorpus.words('123')
# Out:
# ['0', 'Roksan', 'Kandy', 'K2', 'BT', 'amplifier', 'I', ...]

# %%
len(cleared_revs)
# Out:
# 330

# %%
words_rev = []
for fileid in range(len(cleared_revs)):
    words_rev.append(newcorpus.words(str(fileid+1)))

# %%
from nltk.corpus import stopwords
filtered_sentence = []
arev_without_stop_words = ''
stop_words = set(stopwords.words('english'))
for values in words_rev:
    filtered_sentence += [w for w in values if not w.lower() in stop_words]
for values in filtered_sentence:
    arev_without_stop_words += values + ' '

# %%
def bag_of_words(words):
    return dict([(word, True) for word in words])
len(bag_of_words(cleared_revs))
# Out:
# 310

# %%
from nltk.collocations import BigramCollocationFinder
from nltk.metrics import BigramAssocMeasures
from nltk.util import bigrams

def bag_ofbigrams(words):

    return bag_of_words( bigrams(words))


len(bag_ofbigrams(filtered_sentence))
# Out:
# 86251

# %%
bag_ofbigrams(filtered_sentence)
# Out:
# {('0', 'Pass'): True,
#  ('Pass', 'ACA'): True,
#  ('ACA', 'Class'): True,
#  ('Class', 'stereo'): True,
#  ('stereo', 'power'): True,
#  ('power', 'amplifier'): True,
#  ('amplifier', 'DIY'): True,
#  ('DIY', 'design'): True,
#  ('design', 'famous'): True,
#  ('famous', 'designer'): True,
#  ('designer', 'Nelson'): True,
#  ('Nelson', 'Pass'): True,
#  ('Pass', 'meant'): True,
#  ('meant', 'starter'): True,
#  ('starter', 'amplifier'): True,
#  ('amplifier', 'people'): True,
#  ('people', 'new'): True,
#  ('new', 'audio'): True,
#  ('audio', 'electronics'): True,
#  ('electronics', 'build'): True,
#  ('build', 'many'): True,
#  ('many', 'kits'): True,
#  ('kits', 'available'): True,
#  ('available', 'one'): True,
#  ('one', 'loaned'): True,
#  ('loaned', 'long'): True,
#  ('long', 'time'): True,
#  ('time', 'friend'): True,
#  ('friend', 'forum'): True,
#  ('forum', 'kit'): True,
#  ('kit', 'seems'): True,
#  ('seems', 'cost'): True,
#  ('cost', 'around'): True,
#  ('around', 'US'): True,
#  ('US', '320'): True,
#  ('320', 'soThe'): True,
#  ('soThe', 'ACA'): True,
#  ('ACA', 'sample'): True,
#  ('sample', 'received'): True,
#  ('received', 'comes'): True,
#  ('comes', 'attractive'): True,
#  ('attractive', 'black'): True,
#  ('black', 'caseThe'): True,
#  ('caseThe', 'design'): True,
#  ('design', 'Mosfet'): True,
#  ('Mosfet', 'output'): True,
#  ('output', 'stage'): True,
#  ('stage', 'single'): True,
#  ('single', 'stage'): True,
#  ('stage', 'buffer'): True,
#  ('buffer', 'modest'): True,
#  ('modest', 'level'): True,
#  ('level', 'feedback'): True,
#  ('feedback', 'provided'): True,
#  ('provided', 'keep'): True,
#  ('keep', 'distortion'): True,
#  ('distortion', 'somewhat'): True,
#  ('somewhat', 'control'): True,
#  ('control', 'see'): True,
#  ('see', 'gain'): True,
#  ('gain', 'low'): True,
#  ('low', 'requiring'): True,
#  ('requiring', 'full'): True,
#  ('full', '2'): True,
#  ('2', 'volt'): True,
#  ('volt', 'DACs'): True,
#  ('DACs', 'drive'): True,
#  ('drive', 'max'): True,
#  ('max', 'powerHere'): True,
#  ('powerHere', 'back'): True,
#  ('back', 'sideI'): True,
#  ('sideI', 'mess'): True,
#  ('mess', 'assuming'): True,
#  ('assuming', 'single'): True,
#  ('single', 'XLR'): True,
#  ('XLR', 'allows'): True,
#  ('allows', 'bridged'): True,
#  ('bridged', 'mono'): True,
#  ('mono', 'operationPower'): True,
#  ('operationPower', 'provided'): True,
#  ('provided', 'beefy'): True,
#  ('beefy', 'external'): True,
#  ('external', 'switching'): True,
#  ('switching', 'power'): True,
#  ('power', 'supply'): True,
#  ('supply', 'outputs'): True,
#  ('outputs', '24'): True,
#  ('24', 'volts'): True,
#  ('volts', '5'): True,
#  ('5', 'amps'): True,
#  ('amps', '120'): True,
#  ('120', 'watts'): True,
#  ('watts', 'put'): True,
#  ('put', 'use'): True,
#  ('use', 'generating'): True,
#  ('generating', 'copious'): True,
#  ('copious', 'amount'): True,
#  ('amount', 'heat'): True,
#  ('heat', 'told'): True,
#  ('told', 'owner'): True,
#  ('owner', 'let'): True,
#  ('let', 'warm'): True,
#  ('warm', 'minutes'): True,
#  ('minutes', 'see'): True,
#  ('see', 'measurements'): True,
#  ('measurements', 'actually'): True,
#  ('actually', 'made'): True,
#  ('made', 'performance'): True,
#  ('performance', 'worse'): True,
#  ('worse', 'betterOverall'): True,
#  ('betterOverall', 'nice'): True,
#  ('nice', 'package'): True,
#  ('package', 'performsAmplifier'): True,
#  ('performsAmplifier', 'Audio'): True,
#  ('Audio', 'MeasurementsAs'): True,
#  ('MeasurementsAs', 'usual'): True,
#  ('usual', 'start'): True,
#  ('start', 'dashboard'): True,
#  ('dashboard', '5'): True,
#  ('5', 'watt'): True,
#  ('watt', 'output'): True,
#  ('output', '4'): True,
#  ('4', 'ohm'): True,
#  ('ohm', 'Normally'): True,
#  ('Normally', 'well'): True,
#  ('well', 'max'): True,
#  ('max', 'power'): True,
#  ('power', 'case'): True,
#  ('case', 'see'): True,
#  ('see', 'laterGosh'): True,
#  ('laterGosh', 'happened'): True,
#  ('happened', 'aiming'): True,
#  ('aiming', 'high'): True,
#  ('high', 'fidelity'): True,
#  ('fidelity', 'distortionfactory'): True,
#  ('distortionfactory', 'ever'): True,
#  ('ever', 'one'): True,
#  ('one', 'notion'): True,
#  ('notion', 'mostly'): True,
#  ('mostly', 'second'): True,
#  ('second', 'harmonic'): True,
#  ('harmonic', 'hold'): True,
#  ('hold', 'true'): True,
#  ('true', 'either'): True,
#  ('either', 'Welcome'): True,
#  ('Welcome', 'bottom'): True,
#  ('bottom', 'amplifier'): True,
#  ('amplifier', 'ratingsLets'): True,
#  ('ratingsLets', 'dig'): True,
#  ('dig', 'distortion'): True,
#  ('distortion', 'spectrum'): True,
#  ('spectrum', 'lower'): True,
#  ('lower', 'power'): True,
#  ('power', 'level'): True,
#  ('level', '1'): True,
#  ('1', 'wattSecond'): True,
#  ('wattSecond', 'harmonic'): True,
#  ('harmonic', 'dominant'): True,
#  ('dominant', '5'): True,
#  ('watt', 'doesnt'): True,
#  ('doesnt', 'stay'): True,
#  ('stay', 'long'): True,
#  ('long', '2'): True,
#  ('2', 'wattsOur'): True,
#  ('wattsOur', '32tone'): True,
#  ('32tone', 'signal'): True,
#  ('signal', 'resembling'): True,
#  ('resembling', 'music'): True,
#  ('music', 'paints'): True,
#  ('paints', 'ugly'): True,
#  ('ugly', 'picture'): True,
#  ('picture', 'resultI'): True,
#  ('resultI', 'pleasantly'): True,
#  ('pleasantly', 'surprised'): True,
#  ('surprised', 'quiet'): True,
#  ('quiet', 'unit'): True,
#  ('unit', 'thoughFrequency'): True,
#  ('thoughFrequency', 'response'): True,
#  ('response', 'also'): True,
#  ('also', 'well'): True,
#  ('well', 'extendedYou'): True,
#  ('extendedYou', 'may'): True,
#  ('may', 'able'): True,
#  ('able', 'make'): True,
#  ('make', 'radio'): True,
#  ('radio', 'thing'): True,
#  ('thing', 'Back'): True,
#  ('Back', 'ugliness'): True,
#  ('ugliness', 'power'): True,
#  ('power', 'versus'): True,
#  ('versus', 'distortionnoise'): True,
#  ('distortionnoise', '8'): True,
#  ('8', 'ohm'): True,
#  ('ohm', 'loadOh'): True,
#  ('loadOh', 'gosh'): True,
#  ('gosh', '7'): True,
#  ('7', 'watts'): True,
#  ('watts', 'power'): True,
#  ('power', 'SINAD'): True,
#  ('SINAD', '38'): True,
#  ('38', 'dBThings'): True,
#  ('dBThings', 'dont'): True,
#  ('dont', 'get'): True,
#  ('get', 'much'): True,
#  ('much', 'better'): True,
#  ('better', '4'): True,
#  ('ohm', 'loadWe'): True,
#  ('loadWe', 'distortion'): True,
#  ('distortion', 'climbing'): True,
#  ('climbing', 'near'): True,
#  ('near', '10'): True,
#  ('10', 'category'): True,
#  ('category', 'max'): True,
#  ('power', '74'): True,
#  ('74', 'wattschannelThere'): True,
#  ('wattschannelThere', 'little'): True,
#  ('little', 'variation'): True,
#  ('variation', 'response'): True,
#  ('response', 'respect'): True,
#  ('respect', 'frequencyDistortion'): True,
#  ('frequencyDistortion', 'level'): True,
#  ('level', 'high'): True,
#  ('high', 'masking'): True,
#  ('masking', 'secondary'): True,
#  ('secondary', 'sources'): True,
#  ('sources', 'itMaking'): True,
#  ('itMaking', 'sure'): True,
#  ('sure', 'unit'): True,
#  ('unit', 'matches'): True,
#  ('matches', 'reference'): True,
#  ('reference', 'compared'): True,
#  ('compared', 'Nelson'): True,
#  ('Pass', 'publishedWe'): True,
#  ('publishedWe', 'getting'): True,
#  ('getting', 'good'): True,
#  ('good', 'agreement'): True,
#  ('agreement', 'unit'): True,
#  ('unit', 'supposed'): True,
#  ('supposed', 'Nelson'): True,
#  ('Nelson', 'stays'): True,
#  ('stays', '1'): True,
#  ('1', 'watt'): True,
#  ('output', 'shows'): True,
#  ('shows', 'performance'): True,
#  ('performance', 'betterEDIT'): True,
#  ('betterEDIT', 'noted'): True,
#  ('noted', 'dashboard'): True,
#  ('dashboard', 'gain'): True,
#  ('gain', 'much'): True,
#  ('much', 'lower'): True,
#  ('lower', 'spec'): True,
#  ('spec', 'told'): True,
#  ('told', 'version'): True,
#  ('version', '16'): True,
#  ('16', 'tested'): True,
#  ('tested', 'spec'): True,
#  ('spec', '10'): True,
#  ('10', 'dB'): True,
#  ('dB', 'gain'): True,
#  ('gain', 'goodEDIT'): True,
#  ('goodEDIT', '2'): True,
#  ('2', 'See'): True,
#  ('See', 'link'): True,
#  ('link', 'bridged'): True,
#  ('bridged', 'mode'): True,
#  ('mode', 'measurements'): True,
#  ('measurements', 'TestsIs'): True,
#  ('TestsIs', 'thing'): True,
#  ('thing', 'expression'): True,
#  ('expression', 'immediately'): True,
#  ('immediately', 'came'): True,
#  ('came', 'mind'): True,
#  ('mind', 'hooked'): True,
#  ('hooked', 'ACA'): True,
#  ('ACA', 'amp'): True,
#  ('amp', 'Sonus'): True,
#  ('Sonus', 'Faber'): True,
#  ('Faber', 'Concertino'): True,
#  ('Concertino', 'bookshelf'): True,
#  ('bookshelf', 'speaker'): True,
#  ('speaker', 'Granted'): True,
#  ('Granted', 'Concertino'): True,
#  ('Concertino', 'speced'): True,
#  ('speced', '86'): True,
#  ('86', 'dB'): True,
#  ('dB', 'efficiency'): True,
#  ('efficiency', 'come'): True,
#  ('come', 'could'): True,
#  ('could', 'barely'): True,
#  ('barely', 'hear'): True,
#  ('hear', 'bass'): True,
#  ('bass', 'naturally'): True,
#  ('naturally', 'much'): True,
#  ('much', 'either'): True,
#  ('either', 'Topping'): True,
#  ('Topping', 'DX3'): True,
#  ('DX3', 'Pro'): True,
#  ('Pro', 'full'): True,
#  ('full', 'volumeFor'): True,
#  ('volumeFor', 'grins'): True,
#  ('grins', 'plugged'): True,
#  ('plugged', 'US'): True,
#  ('US', '74'): True,
#  ('74', 'tiny'): True,
#  ('tiny', 'little'): True,
#  ('little', 'SMSL'): True,
#  ('SMSL', 'SA100'): True,
#  ('SA100', 'Amplifier'): True,
#  ('Amplifier', 'recently'): True,
#  ('recently', 'reviewed'): True,
#  ('reviewed', 'setup'): True,
#  ('setup', 'speakers'): True,
#  ('speakers', 'came'): True,
#  ('came', 'alive'): True,
#  ('alive', 'lots'): True,
#  ('lots', 'bass'): True,
#  ('bass', 'great'): True,
#  ('great', 'dynamic'): True,
#  ('dynamic', 'range'): True,
#  ('range', 'detail'): True,
#  ('detail', 'Yes'): True,
#  ('Yes', 'amp'): True,
#  ('amp', 'started'): True,
#  ('started', 'cry'): True,
#  ('cry', 'turned'): True,
#  ('turned', 'much'): True,
#  ('much', 'point'): True,
#  ('point', 'left'): True,
#  ('left', 'ACA'): True,
#  ('ACA', 'far'): True,
#  ('far', 'dust'): True,
#  ('dust', 'even'): True,
#  ('even', 'funnyConclusionsAs'): True,
#  ('funnyConclusionsAs', 'starter'): True,
#  ('starter', 'hobby'): True,
#  ('hobby', 'amplifier'): True,
#  ('amplifier', 'get'): True,
#  ('get', 'sound'): True,
#  ('sound', 'coming'): True,
#  ('coming', 'speaker'): True,
#  ('speaker', 'relatively'): True,
#  ('relatively', 'components'): True,
#  ('components', 'Pass'): True,
#  ('Class', 'Amp'): True,
#  ('Amp', 'job'): True,
#  ('job', 'Build'): True,
#  ('Build', 'fun'): True,
#  ('fun', 'put'): True,
#  ('put', 'aside'): True,
#  ('aside', 'get'): True,
#  ('get', 'proper'): True,
#  ('proper', 'amplifier'): True,
#  ('amplifier', 'Amplifiers'): True,
#  ('Amplifiers', 'need'): True,
#  ('need', 'lot'): True,
#  ('lot', 'power'): True,
#  ('power', 'much'): True,
#  ('much', 'less'): True,
#  ('less', 'distortion'): True,
#  ('distortion', 'even'): True,
#  ('even', 'close'): True,
#  ('close', 'folksDo'): True,
#  ('folksDo', 'need'): True,
#  ('need', 'tell'): True,
#  ('tell', 'cant'): True,
#  ('cant', 'recommend'): True,
#  ('recommend', 'Pass'): True,
#  ('ACA', 'hifi'): True,
#  ('hifi', 'listening'): True,
#  ('listening', 'hope'): True,
#  ('hope', '0'): True,
#  ('0', 'McIntosh'): True,
#  ('McIntosh', 'MC462'): True,
#  ('MC462', 'MC462'): True,
#  ('MC462', 'running'): True,
#  ('running', '8'): True,
#  ('ohm', 'output'): True,
#  ('output', 'onethird'): True,
#  ('onethird', 'power'): True,
#  ('power', '30'): True,
#  ('30', 'minutes'): True,
#  ('minutes', '8'): True,
#  ('8', 'ohms'): True,
#  ('ohms', '—'): True,
#  ('—', 'thermally'): True,
#  ('thermally', 'worst'): True,
#  ('worst', 'case'): True,
#  ('case', 'amplifier'): True,
#  ('amplifier', 'classAB'): True,
#  ('classAB', 'classB'): True,
#  ('classB', 'output'): True,
#  ('stage', 'end'): True,
#  ('end', 'time'): True,
#  ('time', 'heatsinks'): True,
#  ('heatsinks', 'hot'): True,
#  ('hot', '1586'): True,
#  ('1586', '°'): True,
#  ('°', 'F'): True,
#  ('F', 'usually'): True,
#  ('usually', 'precondition'): True,
#  ('precondition', 'amplifiers'): True,
#  ('amplifiers', 'hour'): True,
#  ('hour', 'concerned'): True,
#  ('concerned', 'MC462'): True,
#  ('MC462', 'would'): True,
#  ('would', 'get'): True,
#  ('get', 'even'): True,
#  ('even', 'hotterThe'): True,
#  ('hotterThe', 'McIntoshs'): True,
#  ('McIntoshs', 'voltage'): True,
#  ('voltage', 'gain'): True,
#  ('gain', 'varied'): True,
#  ('varied', 'according'): True,
#  ('according', 'output'): True,
#  ('output', 'Autoformer'): True,
#  ('Autoformer', 'tap'): True,
#  ('tap', 'used'): True,
#  ('used', 'whether'): True,
#  ('whether', 'balanced'): True,
#  ('balanced', 'unbalanced'): True,
#  ('unbalanced', 'inputs'): True,
#  ('inputs', 'used'): True,
#  ('used', 'balanced'): True,
#  ('balanced', 'inputs'): True,
#  ('inputs', '8'): True,
#  ('ohm', 'taps'): True,
#  ('taps', 'gain'): True,
#  ('gain', '8'): True,
#  ('ohms', 'lowerthanusual'): True,
#  ('lowerthanusual', '229dB'): True,
#  ('229dB', '4'): True,
#  ('gain', 'lower'): True,
#  ('lower', '204dB'): True,
#  ('204dB', '2'): True,
#  ('2', 'ohms'): True,
#  ('ohms', 'even'): True,
#  ('even', 'lower'): True,
#  ('lower', '174dB'): True,
#  ('174dB', 'gains'): True,
#  ('gains', 'using'): True,
#  ('using', 'unbalanced'): True,
#  ('unbalanced', 'input'): True,
#  ('input', '6dB'): True,
#  ('6dB', 'higher'): True,
#  ('higher', 'rather'): True,
#  ('rather', '6dB'): True,
#  ('6dB', 'lower'): True,
#  ('lower', 'latter'): True,
#  ('latter', 'usually'): True,
#  ('usually', 'case'): True,
#  ('case', 'three'): True,
#  ('three', 'sets'): True,
#  ('sets', 'outputs'): True,
#  ('outputs', 'preserved'): True,
#  ('preserved', 'absolute'): True,
#  ('absolute', 'polarity'): True,
#  ('polarity', 'XLR'): True,
#  ('XLR', 'jacks'): True,
#  ('jacks', 'wired'): True,
#  ('wired', 'pin'): True,
#  ('pin', '2'): True,
#  ('2', 'hot'): True,
#  ('hot', 'modern'): True,
#  ('modern', 'standardThe'): True,
#  ('standardThe', 'MC462s'): True,
#  ('MC462s', 'unbalanced'): True,
#  ('input', 'impedance'): True,
#  ('impedance', 'measured'): True,
#  ('measured', 'close'): True,
#  ('close', 'specified'): True,
#  ('specified', '22k'): True,
#  ('22k', 'ohms'): True,
#  ('ohms', '20Hz'): True,
#  ('20Hz', '20kHz'): True,
#  ('20kHz', 'balanced'): True,
#  ('balanced', 'input'): True,
#  ('impedance', 'twice'): True,
#  ('twice', 'unbalanced'): True,
#  ('unbalanced', 'expected'): True,
#  ('expected', 'output'): True,
#  ('output', 'impedance'): True,
#  ('impedance', 'lowest'): True,
#  ('lowest', '8'): True,
#  ('ohm', 'Autoformer'): True,
#  ('tap', '009'): True,
#  ('009', 'ohm'): True,
#  ('ohm', '20Hz'): True,
#  ('20Hz', '1kHz'): True,
#  ('1kHz', 'rising'): True,
#  ('rising', '013'): True,
#  ('013', 'ohm'): True,
#  ('ohm', '20kHz'): True,
#  ('20kHz', '4'): True,
#  ('taps', 'output'): True,
#  ('impedance', 'almost'): True,
#  ('almost', 'twice'): True,
#  ('twice', '8'): True,
#  ('ohm', 'tap'): True,
#  ('tap', '—'): True,
#  ('—', 'expecting'): True,
#  ('expecting', '—'): True,
#  ('—', '2'): True,
#  ('2', 'ohm'): True,
#  ('taps', '014'): True,
#  ('014', 'ohm'): True,
#  ('ohm', 'low'): True,
#  ('low', 'middle'): True,
#  ('middle', 'frequencies'): True,
#  ('frequencies', 'rising'): True,
#  ('rising', '0185'): True,
#  ('0185', 'ohm'): True,
#  ('ohm', 'top'): True,
#  ('top', 'audioband'): True,
#  ('audioband', 'result'): True,
#  ('result', 'response'): True,
#  ('response', 'standard'): True,
#  ('standard', 'simulated'): True,
#  ('simulated', 'loudspeaker'): True,
#  ('loudspeaker', 'varied'): True,
#  ('varied', '±'): True,
#  ('±', '02dB'): True,
#  ('02dB', 'channels'): True,
#  ('channels', 'levels'): True,
#  ('levels', 'match'): True,
#  ('match', 'within'): True,
#  ('within', '01dB'): True,
#  ('01dB', 'audioband'): True,
#  ('audioband', 'response'): True,
#  ('response', '8'): True,
#  ('ohms', '4'): True,
#  ('4', 'ohms'): True,
#  ('ohms', 'flat'): True,
#  ('flat', '20kHz'): True,
#  ('20kHz', '2'): True,
#  ('ohms', 'slight'): True,
#  ('slight', 'topoctave'): True,
#  ('topoctave', 'rolloff'): True,
#  ('rolloff', 'reaches'): True,
#  ('reaches', '–'): True,
#  ('–', '04dB'): True,
#  ('04dB', '20kHz'): True,
#  ('20kHz', 'MC462'): True,
#  ('MC462', 'reproduced'): True,
#  ('reproduced', '1kHz'): True,
#  ('1kHz', 'squarewave'): True,
#  ('squarewave', 'short'): True,
#  ('short', 'risetimes'): True,
#  ('risetimes', 'flat'): True,
#  ('flat', 'tops'): True,
#  ('tops', 'bottoms'): True,
#  ('bottoms', 'suggesting'): True,
#  ('suggesting', 'amplifiers'): True,
#  ('amplifiers', 'use'): True,
#  ('use', 'output'): True,
#  ('output', 'transformers'): True,
#  ('transformers', 'doesnt'): True,
#  ('doesnt', 'affect'): True,
#  ('affect', 'lowfrequency'): True,
#  ('lowfrequency', 'reproduction'): True,
#  ('reproduction', '10kHz'): True,
#  ('10kHz', 'squarewave'): True,
#  ('squarewave', 'reproduced'): True,
#  ('reproduced', 'without'): True,
#  ('without', 'overshoot'): True,
#  ('overshoot', 'ringing'): True,
#  ('ringing', 'Fig1'): True,
#  ('Fig1', 'McIntosh'): True,
#  ('MC462', 'frequency'): True,
#  ('frequency', 'response'): True,
#  ('response', '283V'): True,
#  ('283V', 'simulated'): True,
#  ('loudspeaker', 'load'): True,
#  ('load', '8'): True,
#  ('ohms', '2'): True,
#  ('ohms', 'Fig2'): True,
#  ('Fig2', 'McIntosh'): True,
#  ('MC462', 'smallsignal'): True,
#  ('smallsignal', '1kHz'): True,
#  ('squarewave', '8'): True,
#  ('8', 'ohmsFig3'): True,
#  ('ohmsFig3', 'McIntosh'): True,
#  ('smallsignal', '10kHz'): True,
#  ('8', 'ohmsThe'): True,
#  ('ohmsThe', 'McIntosh'): True,
#  ('McIntosh', 'MC462s'): True,
#  ('MC462s', 'channel'): True,
#  ('channel', 'separation'): True,
#  ('separation', 'superb'): True,
#  ('superb', 'measuring'): True,
#  ('measuring', 'close'): True,
#  ('close', '120dB'): True,
#  ('120dB', 'directions'): True,
#  ('directions', '1kHz'): True,
#  ('1kHz', 'though'): True,
#  ('though', 'decrease'): True,
#  ('decrease', '70dB'): True,
#  ('70dB', '20kHz'): True,
#  ('20kHz', 'due'): True,
#  ('due', 'capacitive'): True,
#  ('capacitive', 'coupling'): True,
#  ('coupling', 'channels'): True,
#  ('channels', 'point'): True,
#  ('point', 'circuit'): True,
#  ('circuit', 'wideband'): True,
#  ('wideband', 'unweighted'): True,
#  ('unweighted', 'signalnoise'): True,
#  ('signalnoise', 'ratio'): True,
#  ('ratio', 'ref'): True,
#  ('ref', '283V'): True,
#  ('283V', 'measured'): True,
#  ('measured', 'highestgain'): True,
#  ('highestgain', 'output'): True,
#  ('output', 'balanced'): True,
#  ('input', 'shorted'): True,
#  ('shorted', 'ground'): True,
#  ('ground', 'equally'): True,
#  ('equally', 'superb'): True,
#  ('superb', '87dB'): True,
#  ('87dB', 'ratio'): True,
#  ('ratio', 'improved'): True,
#  ('improved', '962dB'): True,
#  ('962dB', 'measurement'): True,
#  ('measurement', 'bandwidth'): True,
#  ('bandwidth', 'restricted'): True,
#  ('restricted', 'audioband'): True,
#  ('audioband', '996dB'): True,
#  ('996dB', 'Aweighted'): True,
#  ('Aweighted', 'Spectral'): True,
#  ('Spectral', 'analysis'): True,
#  ('analysis', 'MC462s'): True,
#  ('MC462s', 'noise'): True,
#  ('noise', 'floor'): True,
#  ('floor', 'revealed'): True,
#  ('revealed', 'spuriae'): True,
#  ('spuriae', '60Hz'): True,
#  ('60Hz', 'oddorder'): True,
#  ('oddorder', 'harmonics'): True,
#  ('harmonics', 'due'): True,
#  ('due', 'magnetic'): True,
#  ('magnetic', 'interference'): True,
#  ('interference', 'AC'): True,
#  ('AC', 'power'): True,
#  ('power', 'transformer'): True,
#  ('transformer', 'spuriae'): True,
#  ('spuriae', 'low'): True,
#  ('low', 'level'): True,
#  ('level', 'however'): True,
#  ('however', 'audibleFig4'): True,
#  ('audibleFig4', 'McIntosh'): True,
#  ('MC462', 'channel'): True,
#  ('channel', 'separationFig5'): True,
#  ('separationFig5', 'McIntosh'): True,
#  ('MC462', 'spectrum'): True,
#  ('spectrum', '1kHz'): True,
#  ('1kHz', 'sinewave'): True,
#  ('sinewave', 'DC'): True,
#  ('DC', '–'): True,
#  ('–', '1kHz'): True,
#  ('1kHz', '1W'): True,
#  ('1W', '8'): True,
#  ('ohms', 'McIntosh'): True,
#  ('McIntosh', 'specifies'): True,
#  ('specifies', 'MC462'): True,
#  ('MC462', 'able'): True,
#  ('able', 'deliver'): True,
#  ('deliver', '450Wpc'): True,
#  ('450Wpc', 'load'): True,
#  ('load', 'matched'): True,
#  ('matched', 'nominal'): True,
#  ('nominal', 'output'): True,
#  ('tap', 'clipping'): True,
#  ('clipping', 'defined'): True,
#  ('defined', 'THDnoise'): True,
#  ('THDnoise', 'reaches'): True,
#  ('reaches', '1'): True,
#  ('1', 'fig6'): True,
#  ('fig6', 'indicates'): True,
#  ('indicates', 'MC462'): True,
#  ('MC462', 'exceeded'): True,
#  ('exceeded', 'specification'): True,
#  ('specification', 'even'): True,
#  ('even', 'channels'): True,
#  ('channels', 'driven'): True,
#  ('driven', '8'): True,
#  ('output', 'clipping'): True,
#  ('clipping', '516Wpc'): True,
#  ('516Wpc', '8'): True,
#  ('ohms', 'trace'): True,
#  ('trace', 'graph'): True,
#  ('graph', 'stops'): True,
#  ('stops', '1'): True,
#  ('1', 'amplifiers'): True,
#  ('amplifiers', 'protection'): True,
#  ('protection', 'triggered'): True,
#  ('triggered', '4'): True,
#  ('ohms', 'McIntoshs'): True,
#  ('McIntoshs', '8'): True,
#  ('output', 'clipped'): True,
#  ('clipped', '720Wpc'): True,
#  ('720Wpc', 'fair'): True,
#  ('fair', 'note'): True,
#  ('note', 'dont'): True,
#  ('dont', 'hold'): True,
#  ('hold', 'wall'): True,
#  ('wall', 'voltage'): True,
#  ('voltage', 'constant'): True,
#  ('constant', 'test'): True,
#  ('test', 'channels'): True,
#  ('channels', 'clipping'): True,
#  ('clipping', '4'): True,
#  ('ohms', 'wall'): True,
#  ('voltage', 'dropped'): True,
#  ('dropped', '121'): True,
#  ('121', '1154V'): True,
#  ('1154V', 'MC462s'): True,
#  ('MC462s', '2'): True,
#  ('output', 'delivered'): True,
#  ('delivered', '190Wpc'): True,
#  ('190Wpc', 'channels'): True,
#  ('ohms', '1'): True,
#  ('1', 'THDN'): True,
#  ('THDN', '298Wpc'): True,
#  ('298Wpc', 'channels'): True,
#  ('driven', '4'): True,
#  ('ohms', '536W'): True,
#  ('536W', 'one'): True,
#  ('one', 'channel'): True,
#  ('channel', 'driven'): True,
#  ('driven', '2'): True,
#  ('ohms', 'Fig6'): True,
#  ('Fig6', 'McIntosh'): True,
#  ('MC462', 'channels'): True,
#  ('driven', 'distortion'): True,
#  ('distortion', 'vs'): True,
#  ('vs', '1kHz'): True,
#  ('1kHz', 'continuous'): True,
#  ('continuous', 'output'): True,
#  ('output', 'power'): True,
#  ('power', '8'): True,
#  ('8', 'ohmsFig7'): True,
#  ('ohmsFig7', 'McIntosh'): True,
#  ('power', '4'): True,
#  ('4', 'ohmsFig8'): True,
#  ('ohmsFig8', 'McIntosh'): True,
#  ('4', 'ohmsFig9'): True,
#  ('ohmsFig9', 'McIntosh'): True,
#  ('power', '2'): True,
#  ('2', 'ohmsFigs'): True,
#  ('ohmsFigs', '6'): True,
#  ('6', '–'): True,
#  ('–', '9'): True,
#  ('9', 'indicate'): True,
#  ('indicate', 'distortion'): True,
#  ('distortion', 'extremely'): True,
#  ('extremely', 'low'): True,
#  ('low', 'lying'): True,
#  ('lying', 'noise'): True,
#  ('floor', 'powers'): True,
#  ('powers', '30W'): True,
#  ('30W', 'therefore'): True,
#  ('therefore', 'plotted'): True,
#  ('plotted', 'THDN'): True,
#  ('THDN', 'changed'): True,
#  ('changed', 'frequency'): True,
#  ('frequency', '8'): True,
#  ('output', 'level'): True,
#  ('level', '283V'): True,
#  ('283V', 'equivalent'): True,
#  ('equivalent', '100W'): True,
#  ('100W', '8'): True,
#  ('ohms', '200W'): True,
#  ('200W', '4'): True,
#  ('ohms', 'could'): True,
#  ('could', 'sure'): True,
#  ('sure', 'looking'): True,
#  ('looking', 'distortion'): True,
#  ('distortion', 'rather'): True,
#  ('rather', 'noise'): True,
#  ('noise', 'result'): True,
#  ('result', 'reveals'): True,
#  ('reveals', 'THD'): True,
#  ('THD', '8'): True,
#  ('ohms', 'rises'): True,
#  ('rises', '1kHz'): True,
#  ('1kHz', 'still'): True,
#  ('still', 'remains'): True,
#  ('remains', '0007'): True,
#  ('0007', 'havent'): True,
#  ('havent', 'shown'): True,
#  ('shown', 'THDN'): True,
#  ('THDN', 'trace'): True,
#  ('trace', '2'): True,
#  ('ohms', 'output'): True,
#  ('output', '2'): True,
#  ('2', 'midrange'): True,
#  ('midrange', 'treble'): True,
#  ('treble', '3'): True,
#  ('3', 'bass'): True,
#  ('bass', '283V'): True,
#  ('equivalent', '400W'): True,
#  ('400W', '2'): True,
#  ('ohms', 'moral'): True,
#  ('moral', 'Match'): True,
#  ('Match', 'MC462s'): True,
#  ('MC462s', 'nominal'): True,
#  ('output', 'lowest'): True,
#  ('lowest', 'impedance'): True,
#  ('impedance', 'magnitude'): True,
#  ('magnitude', 'loudspeaker'): True,
#  ('loudspeaker', 'usedFig10'): True,
#  ('usedFig10', 'McIntosh'): True,
#  ('MC462', 'THDN'): True,
#  ('THDN', 'vs'): True,
#  ('vs', 'frequency'): True,
#  ('frequency', '283V'): True,
#  ('283V', '8'): True,
#  ('ohms', 'distortion'): True,
#  ('distortion', 'signature'): True,
#  ('signature', 'primarily'): True,
#  ('primarily', 'second'): True,
#  ('second', 'third'): True,
#  ('third', 'harmonics'): True,
#  ('harmonics', 'components'): True,
#  ('components', 'low'): True,
#  ('level', 'even'): True,
#  ('even', 'high'): True,
#  ('high', 'powers'): True,
#  ('powers', 'though'): True,
#  ('though', 'right'): True,
#  ('right', 'channel'): True,
#  ('channel', 'slightly'): True,
#  ('slightly', 'distortion'): True,
#  ('distortion', 'left'): True,
#  ('left', 'Tested'): True,
#  ('Tested', 'equal'): True,
#  ('equal', 'mix'): True,
#  ('mix', '19'): True,
#  ('19', '20kHz'): True,
#  ('20kHz', 'tones'): True,
#  ('tones', 'high'): True,
#  ('high', 'power'): True,
#  ('ohms', '8'): True,
#  ('output', 'levels'): True,
#  ('levels', 'higherorder'): True,
#  ('higherorder', 'intermodulation'): True,
#  ('intermodulation', 'products'): True,
#  ('products', 'extremely'): True,
#  ('low', 'secondorder'): True,
#  ('secondorder', 'difference'): True,
#  ('difference', 'product'): True,
#  ('product', '1kHz'): True,
#  ('1kHz', 'lay'): True,
#  ('lay', 'rootsoftheuniverse'): True,
#  ('rootsoftheuniverse', '–'): True,
#  ('–', '114dB'): True,
#  ('114dB', 'Fig11'): True,
#  ('Fig11', 'McIntosh'): True,
#  ('MC462', '1kHz'): True,
#  ('1kHz', 'waveform'): True,
#  ('waveform', '50Wpc'): True,
#  ('50Wpc', '8'): True,
#  ('ohms', '000056'): True,
#  ('000056', 'THDN'): True,
#  ('THDN', 'distortion'): True,
#  ('distortion', 'noise'): True,
#  ('noise', 'waveform'): True,
#  ('waveform', 'fundamental'): True,
#  ('fundamental', 'notched'): True,
#  ('notched', 'Fig12'): True,
#  ('Fig12', 'McIntosh'): True,
#  ('spectrum', '50Hz'): True,
#  ('50Hz', 'sinewave'): True,
#  ('1kHz', '100Wpc'): True,
#  ('100Wpc', '8'): True,
#  ('ohms', 'Fig13'): True,
#  ('Fig13', 'McIntosh'): True,
#  ('MC462', 'HF'): True,
#  ('HF', 'intermodulation'): True,
#  ('intermodulation', 'spectrum'): True,
#  ('spectrum', 'DC'): True,
#  ('–', '30kHz'): True,
#  ('30kHz', '1920kHz'): True,
#  ('1920kHz', '100Wpc'): True,
#  ('100Wpc', 'peak'): True,
#  ('peak', '8'): True,
#  ('ohms', 'Summing'): True,
#  ('Summing', 'McIntosh'): True,
#  ('MC462s', 'measured'): True,
#  ('measured', 'performance'): True,
#  ('performance', 'easy'): True,
#  ('easy', 'extraordinarily'): True,
#  ('extraordinarily', 'wellengineered'): True,
#  ('wellengineered', 'exceptionally'): True,
#  ('exceptionally', 'powerful'): True,
#  ('powerful', 'amplifier'): True,
#  ('amplifier', '0'): True,
#  ('0', 'Primare'): True,
#  ('Primare', 'A358'): True,
#  ('A358', 'A358'): True,
#  ('A358', 'classD'): True,
#  ('classD', 'output'): True,
#  ('output', 'stages'): True,
#  ('stages', 'measurements'): True,
#  ('measurements', 'frequency'): True,
#  ('response', 'taken'): True,
#  ('taken', 'Audio'): True,
#  ('Audio', 'Precisions'): True,
#  ('Precisions', 'auxiliary'): True,
#  ('auxiliary', 'AUX0025'): True,
#  ('AUX0025', 'passive'): True,
#  ('passive', 'lowpass'): True,
#  ('lowpass', 'filter'): True,
#  ('filter', 'mitigates'): True,
#  ('mitigates', 'noise'): True,
#  ('noise', '80kHz'): True,
#  ('80kHz', 'eliminates'): True,
#  ('eliminates', 'noise'): True,
#  ('noise', '200kHz'): True,
#  ('200kHz', 'Without'): True,
#  ('Without', 'filter'): True,
#  ('filter', '325mV'): True,
#  ('325mV', 'ultrasonic'): True,
#  ('ultrasonic', 'noise'): True,
#  ('noise', 'present'): True,
#  ('present', 'pair'): True,
#  ('pair', 'loudspeaker'): True,
#  ('loudspeaker', 'terminals'): True,
#  ('terminals', 'center'): True,
#  ('center', 'frequency'): True,
#  ('frequency', '396kHz'): True,
#  ('396kHz', 'AUX0025'): True,
#  ('AUX0025', 'filter'): True,
#  ('filter', 'twochannel'): True,
#  ('twochannel', 'device'): True,
#  ('device', 'could'): True,
#  ('could', 'measure'): True,
#  ('measure', 'two'): True,
#  ('two', 'Primares'): True,
#  ('Primares', 'eight'): True,
#  ('eight', 'channels'): True,
#  ('channels', 'time'): True,
#  ('time', 'Almost'): True,
#  ('Almost', 'measured'): True,
#  ('performance', 'taken'): True,
#  ('taken', 'channels'): True,
#  ('channels', '6'): True,
#  ('6', '8'): True,
#  ('8', 'bridgedmode'): True,
#  ('bridgedmode', 'tests'): True,
#  ('tests', 'performed'): True,
#  ('performed', 'channels'): True,
#  ('channels', '5'): True,
#  ('5', '6'): True,
#  ('6', 'linked'): True,
#  ('linked', 'channels'): True,
#  ('channels', '7'): True,
#  ('7', '8'): True,
#  ('8', 'linked'): True,
#  ('linked', 'dont'): True,
#  ('dont', 'precondition'): True,
#  ('precondition', 'classD'): True,
#  ('classD', 'amplifiers'): True,
#  ('amplifiers', 'testing'): True,
#  ('testing', 'hours'): True,
#  ('hours', 'operation'): True,
#  ('operation', 'top'): True,
#  ('top', 'panels'): True,
#  ('panels', 'temperature'): True,
#  ('temperature', 'stabilized'): True,
#  ('stabilized', 'warm'): True,
#  ('warm', '1022'): True,
#  ('1022', '°'): True,
#  ('F', 'Primares'): True,
#  ('Primares', 'twochannel'): True,
#  ('twochannel', 'A352'): True,
#  ('A352', 'Herb'): True,
#  ('Herb', 'Reichert'): True,
#  ('Reichert', 'reviewed'): True,
#  ('reviewed', 'May'): True,
#  ('May', '2020'): True,
#  ('2020', 'A358s'): True,
#  ('A358s', 'balanced'): True,
#  ('inputs', 'offered'): True,
#  ('offered', '6dB'): True,
#  ('lower', 'voltage'): True,
#  ('ohms', 'singleended'): True,
#  ('singleended', 'inputs'): True,
#  ('inputs', '1995dB'): True,
#  ('1995dB', 'compared'): True,
#  ('compared', '2595dB'): True,
#  ('2595dB', 'voltage'): True,
#  ('voltage', 'gains'): True,
#  ('gains', 'bridged'): True,
#  ('mode', 'identical'): True,
#  ('identical', 'exactly'): True,
#  ('exactly', '6dB'): True,
#  ('higher', 'bridged'): True,
#  ('bridged', '6'): True,
#  ('6', 'mode'): True,
#  ('mode', 'amplifier'): True,
#  ...}
